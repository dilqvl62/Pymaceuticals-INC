# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)
# Combine the data into a single DataFrame
mouse_study = pd.merge( study_results,mouse_metadata, how = "left", on = "Mouse ID")
# Display the data table for preview
mouse_study.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
mouse_study["Mouse ID"].nunique()
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicated_mice =  mouse_study[mouse_study.duplicated(subset= ['Mouse ID','Timepoint'], keep = False)]["Mouse ID"].unique()
duplicated_mice
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
all_mice_duplicates = mouse_study[mouse_study['Mouse ID'] == 'g989']
all_mice_duplicates
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# 1380     g989         30           59.082294                 1     Propriva
# 1592     g989         35           62.570880                 2     Propriva
#
#          Sex  Age_months  Weight (g)
# 107   Female          21          26
# 137   Female          21          26
# 329   Female          21          26
# 360   Female          21          26
# 620   Female          21          26
# 681   Female          21          26
# 815   Female          21          26
# 869   Female          21          26
# 950   Female          21          26
# 1111  Female          21          26
# 1195  Female          21          26
# 1380  Female          21          26
# 1592  Female          21          26

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
mouse_study_2 = mouse_study.drop(all_mice_duplicates.index, axis = 0)
mouse_study_2.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
mouse_study_2['Mouse ID'].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
mean_tumor = mouse_study_2.groupby('Drug Regimen')['Tumor Volume (mm3)'].mean()
median_tumor = mouse_study_2.groupby('Drug Regimen')['Tumor Volume (mm3)'].median()
variance_tumor= mouse_study_2.groupby('Drug Regimen')['Tumor Volume (mm3)'].var()
std_tumor = mouse_study_2.groupby('Drug Regimen')['Tumor Volume (mm3)'].std()
sem_tumor= mouse_study_2.groupby('Drug Regimen')['Tumor Volume (mm3)'].sem()

# Assemble the resulting series into a single summary DataFrame.
tummor_summary = pd.DataFrame({
                 "Mean Tumor Volum":mean_tumor ,
                 "Median Tumor Volume":median_tumor,
                 "Tumor Volume Variance":variance_tumor,
                 "Tumor Volume Std. Dev.":std_tumor,
                 "Tumor Volume Std. Err.":sem_tumor
})
tummor_summary
# Out:
#               Mean Tumor Volum  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin            40.675741            41.557809              24.947764
# Ceftamin             52.591172            51.776157              39.290177
# Infubinol            52.884795            51.820584              43.128684
# Ketapril             55.235638            53.698743              68.553577
# Naftisol             54.331565            52.509285              66.173479
# Placebo              54.033581            52.288934              61.168083
# Propriva             52.320930            50.446266              43.852013
# Ramicane             40.216745            40.673236              23.486704
# Stelasyn             54.233149            52.431737              59.450562
# Zoniferol            53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# Capomulin                   4.994774                0.329346
# Ceftamin                    6.268188                0.469821
# Infubinol                   6.567243                0.492236
# Ketapril                    8.279709                0.603860
# Naftisol                    8.134708                0.596466
# Placebo                     7.821003                0.581331
# Propriva                    6.622085                0.544332
# Ramicane                    4.846308                0.320955
# Stelasyn                    7.710419                0.573111
# Zoniferol                   6.966589                0.516398

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
summary_stat = mouse_study_2.groupby("Drug Regimen")[['Tumor Volume (mm3)']].agg(['mean', 'median','var','std','sem'])
summary_stat
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
pandas_plot = mouse_study_2.groupby("Drug Regimen")["Mouse ID"].size().sort_values(ascending = False)

pandas_plot.plot(x= "Drug Regimen", kind = 'bar', ylabel = '# of Observed Mouse Timepoints')
# Out:
# <Axes: xlabel='Drug Regimen', ylabel='# of Observed Mouse Timepoints'>

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
plt_plot = mouse_study_2.groupby("Drug Regimen")["Mouse ID"].size().sort_values(ascending = False).reset_index(name ="count")
x_axis = plt_plot['Drug Regimen']
y_axis = plt_plot['count']
plt.xlabel('Drug Regimen')
plt.ylabel('# of observed mouse timepoint')
plt.xticks(rotation =90 )
plt.bar(x_axis, y_axis)
plt.show()

# %%
 # Generate a pie plot showing the distribution of female versus male mice using Pandas
sex = mouse_study_2.groupby('Sex').size()
pandas_plot = sex.plot(kind = 'pie',autopct = "%1.1f%%")
pandas_plot.set_title('Sex', loc = 'left')
pandas_plot
# Out:
# <Axes: title={'left': 'Sex'}>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
sex_category = mouse_study_2.groupby('Sex').size()
sex_category
labels = sex_category.index
values = sex_category.values
plt.title('Sex', loc = 'left',ha = 'center')
plt.pie(values,labels = labels, autopct = "%1.1f%%")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = mouse_study_2.groupby(["Mouse ID",])[["Timepoint"]].max()

Regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
filtred_df = mouse_study_2[mouse_study_2["Drug Regimen"].isin(Regimens) ]

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
final_df = pd.merge(last_timepoint, filtred_df, on = ["Mouse ID", "Timepoint"])
final_df
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0      a203         45           67.973419                 2    Infubinol
# 1      a251         45           65.525743                 1    Infubinol
# 2      a275         45           62.999356                 3     Ceftamin
# 3      a411         45           38.407618                 1     Ramicane
# 4      a444         45           43.047543                 0     Ramicane
# ..      ...        ...                 ...               ...          ...
# 95     y769         45           68.594745                 4     Ceftamin
# 96     y793         45           31.896238                 2    Capomulin
# 97     y865         45           64.729837                 3     Ceftamin
# 98     z578         45           30.638696                 0     Ramicane
# 99     z581         45           62.754451                 3    Infubinol
#
#        Sex  Age_months  Weight (g)
# 0   Female          20          23
# 1   Female          21          25
# 2   Female          20          28
# 3     Male           3          22
# 4   Female          10          25
# ..     ...         ...         ...
# 95  Female           6          27
# 96    Male          17          17
# 97    Male          23          26
# 98    Male          11          16
# 99  Female          24          25
#
# [100 rows x 8 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = final_df["Drug Regimen"].unique().tolist()

# Empty list to fill with tumor vol data (for plotting)
tumor_vol = []

# Calculate the IQR and quantitatively determine if there are any potential outliers.    
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
for treatment in treatments:
    tumor_volume = final_df.loc[final_df["Drug Regimen"]== treatment]["Tumor Volume (mm3)"]
    #tumor_vol += tumor_volume.tolist()
    tumor_vol.append(tumor_volume)
    # Calculate the IQR
    quartiles = tumor_volume.quantile([.25, .5, .75])
    lowerq = quartiles[.25]
    upperq = quartiles[.75]
    iqr = upperq - lowerq
    # Determine outliers using upper and lower bounds
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f"Values below {lower_bound} could be outliers for the Drug {treatment}.")
    print(f"Values above {upper_bound} could be outliers for the Drug {treatment}.")
# Out:
# Values below 36.83290494999999 could be outliers for the Drug Infubinol.
# Values above 82.74144559000001 could be outliers for the Drug Infubinol.
# Values below 25.355449580000002 could be outliers for the Drug Ceftamin.
# Values above 87.66645829999999 could be outliers for the Drug Ceftamin.
# Values below 17.912664470000003 could be outliers for the Drug Ramicane.
# Values above 54.30681135 could be outliers for the Drug Ramicane.
# Values below 20.70456164999999 could be outliers for the Drug Capomulin.
# Values above 51.83201549 could be outliers for the Drug Capomulin.

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.sd
fig1, ax1 = plt.subplots()
ax1.boxplot(tumor_vol, flierprops=dict(markersize = 10, markerfacecolor = 'red'))
ax1.set_ylabel('Final Tumor Volum (mm3)')
ax1.set_xticklabels(treatments)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
single_mouse_tumor_vol= mouse_study_2.loc[(mouse_study_2["Mouse ID"]=='l509') & (mouse_study_2["Drug Regimen"] == 'Capomulin')][["Tumor Volume (mm3)","Timepoint"]]
single_mouse_tumor_vol
x_axis = single_mouse_tumor_vol['Timepoint']
y_axis = single_mouse_tumor_vol['Tumor Volume (mm3)']
plt.title('Capomulin treatment of mouse l509')
plt.xlabel("Timepoint (days)")
plt.ylabel("Tumor Volume (mm3)")
plt.plot(x_axis,y_axis)

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
